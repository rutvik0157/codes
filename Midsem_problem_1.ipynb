# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data= pd.read_csv('/content/material_data_Alankar.txt')
data
# Out:
#    Elements  Atomic_Number  Electronegativity  Atomic_Radius  \
# 0         H              1               2.20           0.25
# 1        He              2               0.00           1.20
# 2        Li              3               0.98           1.45
# 3        Be              4               1.57           1.05
# 4         B              5               2.04           0.85
# ..      ...            ...                ...            ...
# 90        U             92               1.38           1.75
# 91       Np             93               1.36           1.75
# 92       Pu             94               1.28           1.75
# 93       Am             95               1.30           1.75
# 94       Cm             96               1.30           1.76
#
#     Thermal_Conductivity   Density Crystal_System
# 0                 0.1805      0.09            HEX
# 1                 0.1513      0.18            HCP
# 2                85.0000    530.00            BCC
# ...

# %%
scaler_data= data[['Atomic_Number','Electronegativity','Atomic_Radius','Density','Thermal_Conductivity']]
scaler_data
# Out:
#     Atomic_Number  Electronegativity  Atomic_Radius   Density  \
# 0               1               2.20           0.25      0.09
# 1               2               0.00           1.20      0.18
# 2               3               0.98           1.45    530.00
# 3               4               1.57           1.05   1850.00
# 4               5               2.04           0.85   2340.00
# ..            ...                ...            ...       ...
# 90             92               1.38           1.75  18950.00
# 91             93               1.36           1.75  20200.00
# 92             94               1.28           1.75  19840.00
# 93             95               1.30           1.75  13670.00
# 94             96               1.30           1.76  13500.00
#
#     Thermal_Conductivity
# 0                 0.1805
# 1                 0.1513
# 2                85.0000
# 3               190.0000
# 4                27.0000
# ..                   ...
# 90               27.0000
# ...

# %%
X=scaler_data[['Atomic_Number','Electronegativity','Atomic_Radius','Density']]
Y=scaler_data[['Thermal_Conductivity']]

# %%
X
# Out:
#     Atomic_Number  Electronegativity  Atomic_Radius   Density
# 0               1               2.20           0.25      0.09
# 1               2               0.00           1.20      0.18
# 2               3               0.98           1.45    530.00
# 3               4               1.57           1.05   1850.00
# 4               5               2.04           0.85   2340.00
# ..            ...                ...            ...       ...
# 90             92               1.38           1.75  18950.00
# 91             93               1.36           1.75  20200.00
# 92             94               1.28           1.75  19840.00
# 93             95               1.30           1.75  13670.00
# 94             96               1.30           1.76  13500.00
#
# [95 rows x 4 columns]

# %%
Y
# Out:
#     Thermal_Conductivity
# 0                 0.1805
# 1                 0.1513
# 2                85.0000
# 3               190.0000
# 4                27.0000
# ..                   ...
# 90               27.0000
# 91                6.0000
# 92                6.0000
# 93               10.0000
# 94                8.8000
#
# [95 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train
# Out:
#     Atomic_Number  Electronegativity  Atomic_Radius  Density
# 66             67               1.24           1.75   8800.0
# 15             16               2.58           1.00   2070.0
# 78             79               2.54           1.35  19320.0
# 79             80               2.00           1.50  13550.0
# 30             31               1.81           1.30   5910.0
# ..            ...                ...            ...      ...
# 60             61               1.13           1.85   7300.0
# 71             72               1.30           1.55  13310.0
# 14             15               2.19           1.00   1820.0
# 92             94               1.28           1.75  19840.0
# 51             52               2.10           1.40   6240.0
#
# [76 rows x 4 columns]

# %%
X_train.shape
# Out:
# (76, 4)

# %%
X_test
# Out:
#     Atomic_Number  Electronegativity  Atomic_Radius   Density
# 68             69               1.25           1.75   9320.00
# 22             23               1.63           1.35   6110.00
# 72             73               1.50           1.45  16650.00
# 73             74               2.36           1.35  19350.00
# 0               1               2.20           0.25      0.09
# 26             27               1.88           1.35   8900.00
# 40             41               1.60           1.45   8570.00
# 42             43               1.90           1.35  11500.00
# 10             11               0.93           1.80    970.00
# 45             46               2.20           1.40  12020.00
# 84             85               2.20           1.27   6350.00
# 55             56               0.89           2.15   3590.00
# 81             82               2.33           1.80  11350.00
# 47             48               1.69           1.55   8650.00
# ...

# %%
X_test.shape
# Out:
# (19, 4)

# %%
Y_train
# Out:
#     Thermal_Conductivity
# 66                16.000
# 15                 0.205
# 78               320.000
# 79                 8.300
# 30                29.000
# ..                   ...
# 60                15.000
# 71                23.000
# 14                 0.236
# 92                 6.000
# 51                 3.000
#
# [76 rows x 1 columns]

# %%
Y_test
# Out:
#     Thermal_Conductivity
# 68               17.0000
# 22               31.0000
# 72               57.0000
# 73              170.0000
# 0                 0.1805
# 26              100.0000
# 40               54.0000
# 42               51.0000
# 10              140.0000
# 45               72.0000
# 84                2.0000
# 55               18.0000
# 81               35.0000
# 47               97.0000
# 12              235.0000
# 4                27.0000
# 18              100.0000
# 28              400.0000
# 39               23.0000

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,r2_score
model=linear_model.LinearRegression()
model.fit(X_train,Y_train)
Y_predicted=model.predict(X_test)
Y_predicted=pd.DataFrame(Y_predicted)

Y_predicted
# Out:
#              0
# 0    35.412414
# 1    85.134526
# 2    77.813781
# 3   100.417979
# 4    34.170187
# 5   102.422086
# 6    74.196515
# 7    92.668134
# 8    80.137928
# 9    95.428046
# 10  -34.980783
# 11   27.769452
# 12   36.703425
# 13   65.971399
# 14   71.895079
# 15   70.593905
# 16   79.830042
# 17   99.108649
# 18   61.256206

# %%
print("mean squared error",np.sqrt(mean_squared_error(Y_test,Y_predicted)))
print('R^2 value',r2_score(Y_test,Y_predicted))
# Out:
# mean squared error 85.63090427052524
# R^2 value 0.1873934798632333

# %%
plt.scatter(Y_predicted,Y_test,color='red')
plt.xlabel('Y_predicted')
plt.ylabel("Y_test")
plt.title('thermal conductivity')
legend_text = f' RMSE = {np.sqrt(mean_squared_error(Y_test,Y_predicted)):.2f}\n R^2 = {r2_score(Y_test,Y_predicted):.2f}'
plt.figtext(0.95, 0.5, legend_text, fontsize=10, ha='left')

plt.show()
