# %% [markdown]
# ### Random Forest Regression

# %%
# import numpy package for arrays and stuff 
import numpy as np  
  
# import matplotlib.pyplot for plotting our result 
import matplotlib.pyplot as plt 
  
# import pandas for importing csv files  
import pandas as pd

# %%
# import dataset 
dataset = pd.read_csv('material_data.txt')  
# alternatively open up .csv file to read data

# %%
dataset.head()
# Out:
#   Elements  Atomic_Number  Electronegativity  Atomic_Radius  \
# 0        H              1               2.20           0.25
# 1       He              2               0.00           1.20
# 2       Li              3               0.98           1.45
# 3       Be              4               1.57           1.05
# 4        B              5               2.04           0.85
#
#    Thermal_Conductivity  Density Crystal_System
# 0                0.1805     0.09            HEX
# 1                0.1513     0.18            HCP
# 2               85.0000   530.00            BCC
# 3              190.0000  1850.00            HCP
# 4               27.0000  2340.00            RHO

# %% [markdown]
# ### In the above dataset, I would like to predict Thermal Conductivity based on Electronegatviity, Atomic Radius and Density.

# %%
#X = dataset[['Electronegativity','Atomic_Radius','Density']]
X = dataset[['Density']]

# %%
X
# Out:
#      Density
# 0       0.09
# 1       0.18
# 2     530.00
# 3    1850.00
# 4    2340.00
# ..       ...
# 90  18950.00
# 91  20200.00
# 92  19840.00
# 93  13670.00
# 94  13500.00
#
# [95 rows x 1 columns]

# %%
print(X)
X.dtypes
# Out:
#      Density
# 0       0.09
# 1       0.18
# 2     530.00
# 3    1850.00
# 4    2340.00
# ..       ...
# 90  18950.00
# 91  20200.00
# 92  19840.00
# 93  13670.00
# 94  13500.00
#
# [95 rows x 1 columns]
# Density    float64
# dtype: object

# %%
Y = dataset[['Thermal_Conductivity']]

# %%
Y
Y.dtypes
# Out:
# Thermal_Conductivity    float64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
import seaborn as sns
import sklearn
import warnings
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

warnings.filterwarnings('ignore')

# %% [raw]
# # create a regressor object
# regressor = RandomForestRegressor(n_estimators=10, random_state=True, oob_score=True)
# X_train, X_test, Y_train, Y_test = train_test_split(
#     X, Y, test_size=0.15, random_state=0)
# # fit the regressor with X and Y data
# regressor.fit(X_train, Y_train)

# %%
# predicting a new value 
  
Y_train_pred = regressor.predict(X_train) 
Y_test_pred = regressor.predict(X_test) 
  
# print the predicted price 
Y_test_pred
# Out:
# array([1.08000e+02, 4.00000e+01, 2.78000e+01, 2.03920e-02, 7.22000e+01,
#        7.80000e+00, 3.34000e+01, 6.48000e+01, 1.23796e+01, 1.52000e+01,
#        5.20000e+01, 2.58300e-02, 1.62000e+01, 2.27200e+02, 1.52000e+01])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(Y_train, Y_train_pred, color = 'red')
plt.show()

# %%
plt.scatter(Y_test, Y_test_pred, color = 'red')
plt.show()

# %%
# Evaluating the model
from sklearn.metrics import mean_squared_error, r2_score

oob_score = regressor.oob_score_
print(f'Out-of-Bag Score: {oob_score}')
  
# Evaluating the model for training data
mse_train = mean_squared_error(Y_train, Y_train_pred)
print(f'Mean Squared Error for training data: {mse_train}')
 
r2_train = r2_score(Y_train, Y_train_pred)
print(f'R-squared for training data: {r2_train}')

# Evaluating the model for test data
mse_test = mean_squared_error(Y_test, Y_test_pred)
print(f'Mean Squared Error for test data: {mse_test}')
 
r2_test = r2_score(Y_test, Y_test_pred)
print(f'R-squared for test data: {r2_test}')
# Out:
# Out-of-Bag Score: -0.7742290644367675
# Mean Squared Error for training data: 1596.430657039756
# R-squared for training data: 0.7722325446840405
# Mean Squared Error for test data: 3851.0813496525707
# R-squared for test data: -0.5780749062301229

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
 
# Assuming regressor is your trained Random Forest model
# Pick one tree from the forest, e.g., the first tree (index 0)
tree_to_plot = regressor.estimators_[0]
 
# Plot the decision tree
plt.figure(figsize=(20, 10))
plot_tree(tree_to_plot, feature_names=dataset.columns.tolist(), filled=True, rounded=True, fontsize=8)
plt.title("Decision Tree from Random Forest")
plt.show()

# %%
|
